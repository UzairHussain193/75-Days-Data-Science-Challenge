# %% [markdown]
# ## Data Analysis with Python: Zero to Pandas - Course Project Guidelines
# #### (remove this cell before submission)
#
# Important links:
# - Make submissions here: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/course-project
# - Ask questions here: https://jovian.ml/forum/t/course-project-on-exploratory-data-analysis-discuss-and-share-your-work/11684
# - Find interesting datasets here: https://jovian.ml/forum/t/recommended-datasets-for-course-project/11711
#
#
# This is the starter notebook for the course project for [Data Analysis with Python: Zero to Pandas](https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas). You will pick a real-world dataset of your choice and apply the concepts learned in this course to perform exploratory data analysis. Use this starter notebook as an outline for your project . Focus on documentation and presentation - this Jupyter notebook will also serve as a project report, so make sure to include detailed explanations wherever possible using Markdown cells.
#
# ### Evaluation Criteria
#
# Your submission will be evaluated using the following criteria:
#
# * Dataset must contain at least 3 columns and 150 rows of data
# * You must ask and answer at least 4 questions about the dataset
# * Your submission must include at least 4 visualizations (graphs)
# * Your submission must include explanations using markdown cells, apart from the code.
# * Your work must not be plagiarized i.e. copy-pasted for somewhere else.
#
#
# Follow this step-by-step guide to work on your project.
#
#
# ### Step 1: Select a real-world dataset
#
# - Find an interesting dataset on this page: https://www.kaggle.com/datasets?fileType=csv
# - The data should be in CSV format, and should contain at least 3 columns and 150 rows
# - Download the dataset using the [`opendatasets` Python library](https://github.com/JovianML/opendatasets#opendatasets)
#
# Here's some sample code for downloading the [US Elections Dataset](https://www.kaggle.com/tunguz/us-elections-dataset):
#
# ```
# import opendatasets as od
# dataset_url = 'https://www.kaggle.com/tunguz/us-elections-dataset'
# od.download('https://www.kaggle.com/tunguz/us-elections-dataset')
# ```
#
# You can find a list of recommended datasets here: https://jovian.ml/forum/t/recommended-datasets-for-course-project/11711
#
# ### Step 2: Perform data preparation & cleaning
#
# - Load the dataset into a data frame using Pandas
# - Explore the number of rows & columns, ranges of values etc.
# - Handle missing, incorrect and invalid data
# - Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)
#
#
# ### Step 3: Perform exploratory analysis & visualization
#
# - Compute the mean, sum, range and other interesting statistics for numeric columns
# - Explore distributions of numeric columns using histograms etc.
# - Explore relationship between columns using scatter plots, bar charts etc.
# - Make a note of interesting insights from the exploratory analysis
#
# ### Step 4: Ask & answer questions about the data
#
# - Ask at least 4 interesting questions about your dataset
# - Answer the questions either by computing the results using Numpy/Pandas or by plotting graphs using Matplotlib/Seaborn
# - Create new columns, merge multiple dataset and perform grouping/aggregation wherever necessary
# - Wherever you're using a library function from Pandas/Numpy/Matplotlib etc. explain briefly what it does
#
#
# ### Step 5: Summarize your inferences & write a conclusion
#
# - Write a summary of what you've learned from the analysis
# - Include interesting insights and graphs from previous sections
# - Share ideas for future work on the same topic using other relevant datasets
# - Share links to resources you found useful during your analysis
#
#
# ### Step 6: Make a submission & share your work
#
# - Upload your notebook to your Jovian.ml profile using `jovian.commit`.
# - **Make a submission here**: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/course-project
# - Share your work on the forum: https://jovian.ml/forum/t/course-project-on-exploratory-data-analysis-discuss-and-share-your-work/11684
# - Browse through projects shared by other participants and give feedback
#
#
# ### (Optional) Step 7: Write a blog post
#
# - A blog post is a great way to present and showcase your work.
# - Sign up on [Medium.com](https://medium.com) to write a blog post for your project.
# - Copy over the explanations from your Jupyter notebook into your blog post, and [embed code cells & outputs](https://medium.com/jovianml/share-and-embed-jupyter-notebooks-online-with-jovian-ml-df709a03064e)
# - Check out the Jovian.ml Medium publication for inspiration: https://medium.com/jovianml
#
#
#
#
#
# ### Example Projects
#
# Refer to these projects for inspiration:
#
# * [Analyzing StackOverflow Developer Survey Results](https://jovian.ml/aakashns/python-eda-stackoverflow-survey)
#
# * [Analyzing Covid-19 data using Pandas](https://jovian.ml/aakashns/python-pandas-data-analysis)
#
# * [Analyzing your browser history using Pandas & Seaborn](https://medium.com/free-code-camp/understanding-my-browsing-pattern-using-pandas-and-seaborn-162b97e33e51) by Kartik Godawat
#
# * [WhatsApp Chat Data Analysis](https://jovian.ml/PrajwalPrashanth/whatsapp-chat-data-analysis) by Prajwal Prashanth
#
# * [Understanding the Gender Divide in Data Science Roles](https://medium.com/datadriveninvestor/exploratory-data-analysis-eda-understanding-the-gender-divide-in-data-science-roles-9faa5da44f5b) by Aakanksha N S
#
# * [2019 State of Javscript Survey Results](https://2019.stateofjs.com/demographics/)
#
# * [2020 Stack Overflow Developer Survey Results](https://insights.stackoverflow.com/survey/2020)
#
#
#
# **NOTE**: Remove this cell containing the instructions before making your submission. You can do using the "Edit > Delete Cells" menu option.

# %% [markdown]
# # Data Analysis over Chronic Kidney Disease Dataset

# %% [markdown]
# # Data Analysis over Chronic Kidney Disease Dataset
#
# TODO - Write some introduction about your project here: describe the dataset, where you got it from, what you're trying to do with it, and which tools & techniques you're using. You can also mention about the course [Data Analysis with Python: Zero to Pandas](zerotopandas.com), and what you've learned from it.

# %% [markdown]
# ### How to run the code
#
# This is an executable [*Jupyter notebook*](https://jupyter.org) hosted on [Jovian.ml](https://www.jovian.ml), a platform for sharing data science projects. You can run and experiment with the code in a couple of ways: *using free online resources* (recommended) or *on your own computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing this notebook is to click the "Run" button at the top of this page, and select "Run on Binder". This will run the notebook on [mybinder.org](https://mybinder.org), a free online service for running Jupyter notebooks. You can also select "Run on Colab" or "Run on Kaggle".
#
#
# #### Option 2: Running on your computer locally
#
# 1. Install Conda by [following these instructions](https://conda.io/projects/conda/en/latest/user-guide/install/index.html). Add Conda binaries to your system `PATH`, so you can use the `conda` command on your terminal.
#
# 2. Create a Conda environment and install the required libraries by running these commands on the terminal:
#
# ```
# conda create -n zerotopandas -y python=3.8
# conda activate zerotopandas
# pip install jovian jupyter numpy pandas matplotlib seaborn opendatasets --upgrade
# ```
#
# 3. Press the "Clone" button above to copy the command for downloading the notebook, and run it on the terminal. This will create a new directory and download the notebook. The command will look something like this:
#
# ```
# jovian clone notebook-owner/notebook-id
# ```
#
#
#
# 4. Enter the newly created directory using `cd directory-name` and start the Jupyter notebook.
#
# ```
# jupyter notebook
# ```
#
# You can now access Jupyter's web interface by clicking the link that shows up on the terminal or by visiting http://localhost:8888 on your browser. Click on the notebook file (it has a `.ipynb` extension) to open it.

# %% [markdown]
# # Data Analysis over Chronic Kidney Disease Dataset

# %% [markdown]
# ## Downloading the Dataset
#
# **TODO** - add some explanation here

# %% [markdown]
# > Instructions for downloading the dataset (delete this cell)
# >
# > - Find an interesting dataset on this page: https://www.kaggle.com/datasets?fileType=csv
# > - The data should be in CSV format, and should contain at least 3 columns and 150 rows
# > - Download the dataset using the [`opendatasets` Python library](https://github.com/JovianML/opendatasets#opendatasets)

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
# Change this
dataset_url = 'https://www.kaggle.com/datasets/rabieelkharoua/chronic-kidney-disease-dataset-analysis'

# %%
# dataset_url = "https://www.kaggle.com/datasets/notkrishna/cricket-statistics-for-all-formats"
# # this dataset includes all the tournament stats as well.

# %%
# pip install opendatasets

# %%
import opendatasets as od # type: ignore
od.download(dataset_url)
# Out:
# Skipping, found downloaded files in ".\chronic-kidney-disease-dataset-analysis" (use force=True to force download)

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
# Change this
data_dir = './chronic-kidney-disease-dataset-analysis'

# %%
import os
os.listdir(data_dir)
# Out:
# ['Chronic_Kidney_Dsease_data.csv']

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
# project_name = "zerotopandas-course-project-starter" # change this (use lowercase letters and hyphens only)

filename = "zerotopandas-course-project.ipynb"

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
# jovian.commit(project=project_name)
# jovian.commit(filename=filename)

# %% [markdown]
# ## Data Preparation and Cleaning
#
# **TODO** - Write some explanation here.

# %% [markdown]
# > Instructions (delete this cell):
# >
# > - Load the dataset into a data frame using Pandas
# > - Explore the number of rows & columns, ranges of values etc.
# > - Handle missing, incorrect and invalid data
# > - Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./chronic-kidney-disease-dataset-analysis/Chronic_Kidney_Dsease_data.csv')

# %%
df.shape
# Out:
# (1659, 54)

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0          1   71       0          0                    0               2
# 1          2   34       0          0                    1               3
# 2          3   80       1          1                    0               1
# 3          4   40       0          2                    0               1
# 4          5   43       0          1                    1               2
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...   Itching  \
# 0  31.069414        1            5.128112          1.676220  ...  7.556302
# 1  29.692119        1           18.609552          8.377574  ...  6.836766
# 2  37.394822        1           11.882429          9.607401  ...  2.144722
# 3  31.329680        0           16.020165          0.408871  ...  7.077188
# 4  23.726311        0            7.944146          0.780319  ...  3.553118
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1659 entries, 0 to 1658
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PatientID                      1659 non-null   int64
#  1   Age                            1659 non-null   int64
#  2   Gender                         1659 non-null   int64
#  3   Ethnicity                      1659 non-null   int64
#  4   SocioeconomicStatus            1659 non-null   int64
#  5   EducationLevel                 1659 non-null   int64
#  6   BMI                            1659 non-null   float64
#  7   Smoking                        1659 non-null   int64
#  8   AlcoholConsumption             1659 non-null   float64
#  9   PhysicalActivity               1659 non-null   float64
#  10  DietQuality                    1659 non-null   float64
#  11  SleepQuality                   1659 non-null   float64
# ...

# %%
df.describe()
# Out:
#          PatientID          Age       Gender   Ethnicity  SocioeconomicStatus  \
# count  1659.000000  1659.000000  1659.000000  1659.00000          1659.000000
# mean    830.000000    54.441230     0.515371     0.71308             0.977697
# std     479.056364    20.549757     0.499914     1.00043             0.776686
# min       1.000000    20.000000     0.000000     0.00000             0.000000
# 25%     415.500000    36.000000     0.000000     0.00000             0.000000
# 50%     830.000000    54.000000     1.000000     0.00000             1.000000
# 75%    1244.500000    72.000000     1.000000     1.00000             2.000000
# max    1659.000000    90.000000     1.000000     3.00000             2.000000
#
#        EducationLevel          BMI      Smoking  AlcoholConsumption  \
# count     1659.000000  1659.000000  1659.000000         1659.000000
# mean         1.693189    27.620049     0.292948            9.969831
# ...

# %%
df.isnull().sum()
# Out:
# PatientID                        0
# Age                              0
# Gender                           0
# Ethnicity                        0
# SocioeconomicStatus              0
# EducationLevel                   0
# BMI                              0
# Smoking                          0
# AlcoholConsumption               0
# PhysicalActivity                 0
# DietQuality                      0
# SleepQuality                     0
# FamilyHistoryKidneyDisease       0
# FamilyHistoryHypertension        0
# FamilyHistoryDiabetes            0
# PreviousAcuteKidneyInjury        0
# UrinaryTractInfections           0
# SystolicBP                       0
# DiastolicBP                      0
# FastingBloodSugar                0
# HbA1c                            0
# SerumCreatinine                  0
# BUNLevels                        0
# GFR                              0
# ProteinInUrine                   0
# ACR                              0
# SerumElectrolytesSodium          0
# ...

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryKidneyDisease', 'FamilyHistoryHypertension',
#        'FamilyHistoryDiabetes', 'PreviousAcuteKidneyInjury',
#        'UrinaryTractInfections', 'SystolicBP', 'DiastolicBP',
#        'FastingBloodSugar', 'HbA1c', 'SerumCreatinine', 'BUNLevels', 'GFR',
#        'ProteinInUrine', 'ACR', 'SerumElectrolytesSodium',
#        'SerumElectrolytesPotassium', 'SerumElectrolytesCalcium',
#        'SerumElectrolytesPhosphorus', 'HemoglobinLevels', 'CholesterolTotal',
#        'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides',
#        'ACEInhibitors', 'Diuretics', 'NSAIDsUse', 'Statins',
#        'AntidiabeticMedications', 'Edema', 'FatigueLevels', 'NauseaVomiting',
#        'MuscleCramps', 'Itching', 'QualityOfLifeScore', 'HeavyMetalsExposure',
# ...

# %%
# import jovian

# %%
# jovian.commit()

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# **TODO** - write some explanation here.

# %% [markdown]
# > Instructions (delete this cell)
# >
# > - Compute the mean, sum, range and other interesting statistics for numeric columns
# > - Explore distributions of numeric columns using histograms etc.
# > - Explore relationship between columns using scatter plots, bar charts etc.
# > - Make a note of interesting insights from the exploratory analysis

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryKidneyDisease', 'FamilyHistoryHypertension',
#        'FamilyHistoryDiabetes', 'PreviousAcuteKidneyInjury',
#        'UrinaryTractInfections', 'SystolicBP', 'DiastolicBP',
#        'FastingBloodSugar', 'HbA1c', 'SerumCreatinine', 'BUNLevels', 'GFR',
#        'ProteinInUrine', 'ACR', 'SerumElectrolytesSodium',
#        'SerumElectrolytesPotassium', 'SerumElectrolytesCalcium',
#        'SerumElectrolytesPhosphorus', 'HemoglobinLevels', 'CholesterolTotal',
#        'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides',
#        'ACEInhibitors', 'Diuretics', 'NSAIDsUse', 'Statins',
#        'AntidiabeticMedications', 'Edema', 'FatigueLevels', 'NauseaVomiting',
#        'MuscleCramps', 'Itching', 'QualityOfLifeScore', 'HeavyMetalsExposure',
# ...

# %%
plt.scatter(df['Age'],df['AlcoholConsumption'] );
plt.xlabel('Age')
plt.ylabel('AlcoholConsumption')
plt.title('Age vs AlcoholConsumption')
# Out:
# Text(0.5, 1.0, 'Age vs AlcoholConsumption')

# %% [markdown]
# ### Explanation of the Plot
#
# The scatter plot generated by this code will show a series of points on a graph, where:
#
# - The x-axis represents the age of individuals.
# - The y-axis represents their alcohol consumption levels.
#
# Each point on the plot corresponds to an individual in the dataset. The position of the point is determined by the individual's age (on the x-axis) and their alcohol consumption (on the y-axis).
#
# By examining the scatter plot, you can identify patterns or relationships between age and alcohol consumption. For instance, you might observe trends such as:
#
# - Whether alcohol consumption increases or decreases with age.
# - The spread or variability of alcohol consumption across different age groups.
# - Any outliers or unusual data points that stand out.
#
# This visualization helps in understanding how age might be related to alcohol consumption in the given dataset.

# %% [markdown]
# ---
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
df.head(5)
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0          1   71       0          0                    0               2
# 1          2   34       0          0                    1               3
# 2          3   80       1          1                    0               1
# 3          4   40       0          2                    0               1
# 4          5   43       0          1                    1               2
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...   Itching  \
# 0  31.069414        1            5.128112          1.676220  ...  7.556302
# 1  29.692119        1           18.609552          8.377574  ...  6.836766
# 2  37.394822        1           11.882429          9.607401  ...  2.144722
# 3  31.329680        0           16.020165          0.408871  ...  7.077188
# 4  23.726311        0            7.944146          0.780319  ...  3.553118
#
# ...

# %%
plt.hist(df['HealthLiteracy'], bins=20, color='orange', edgecolor='black');
plt.xlabel('HealthLiteracy')
plt.ylabel('Count')
plt.title('Distribution of HealthLiteracy')
# Out:
# Text(0.5, 1.0, 'Distribution of HealthLiteracy')

# %% [markdown]
# ### Explanation of the Plot
#
# The histogram generated by this code will show a distribution of values on a graph, where:
#
# - The x-axis represents the health literacy scores of individuals.
# - The y-axis represents the count of individuals with each health literacy score.
#
# Each bar on the plot corresponds to a range of health literacy scores, as defined by the `bins` parameter.
#
# By examining the histogram, you can identify patterns or characteristics of the health literacy scores. For instance, you might observe trends such as:
#
# - The overall shape of the distribution (e.g., normal, skewed, uniform).
# - The range of health literacy scores that occur most frequently.
# - Any gaps or outliers in the distribution.
#
# This visualization helps in understanding the distribution of health literacy scores within the given dataset.

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
# Explore one or more columns by plotting a graph below, and add some explanation about it.
sns.scatterplot(x='Age', y='AlcoholConsumption', data=df)
plt.xlabel('Age')
plt.ylabel('AlcoholConsumption')
plt.title('Age vs AlcoholConsumption')
# Out:
# Text(0.5, 1.0, 'Age vs AlcoholConsumption')

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryKidneyDisease', 'FamilyHistoryHypertension',
#        'FamilyHistoryDiabetes', 'PreviousAcuteKidneyInjury',
#        'UrinaryTractInfections', 'SystolicBP', 'DiastolicBP',
#        'FastingBloodSugar', 'HbA1c', 'SerumCreatinine', 'BUNLevels', 'GFR',
#        'ProteinInUrine', 'ACR', 'SerumElectrolytesSodium',
#        'SerumElectrolytesPotassium', 'SerumElectrolytesCalcium',
#        'SerumElectrolytesPhosphorus', 'HemoglobinLevels', 'CholesterolTotal',
#        'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides',
#        'ACEInhibitors', 'Diuretics', 'NSAIDsUse', 'Statins',
#        'AntidiabeticMedications', 'Edema', 'FatigueLevels', 'NauseaVomiting',
#        'MuscleCramps', 'Itching', 'QualityOfLifeScore', 'HeavyMetalsExposure',
# ...

# %%
# Bar chart: Count of Patients by Socioeconomic Status
df['SocioeconomicStatus'].value_counts().plot(kind='bar')
plt.xlabel('Socioeconomic Status')
plt.ylabel('Count')
plt.title('Count of Patients by Socioeconomic Status')
plt.show()

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
# Box plot: BMI across different Genders
df.boxplot(column='BMI', by='Gender')
plt.xlabel('Gender')
plt.ylabel('BMI')
plt.title('BMI Distribution by Gender')
plt.suptitle('')
plt.show()

# %% [markdown]
# **TODO** - Explore one or more columns by plotting a graph below, and add some explanation about it

# %%
# KDE plot: Distribution of Age
sns.kdeplot(df['Age'], shade=True);
plt.xlabel('Age');
plt.title('Density Plot of Age');
plt.show();
# Out:
# C:\Users\Uzair Hussain\AppData\Local\Temp\ipykernel_8928\17354329.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Age'], shade=True);

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %%
# import jovian

# %%
# jovian.commit()

# %% [markdown]
# ## Asking and Answering Questions
#
# TODO - write some explanation here.

# %% [markdown]
# > Instructions (delete this cell)
# >
# > - Ask at least 5 interesting questions about your dataset
# > - Answer the questions either by computing the results using Numpy/Pandas or by plotting graphs using Matplotlib/Seaborn
# > - Create new columns, merge multiple dataset and perform grouping/aggregation wherever necessary
# > - Wherever you're using a library function from Pandas/Numpy/Matplotlib etc. explain briefly what it does

# %% [markdown]
# #### Question 1: What is the average BMI for each gender?

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryKidneyDisease', 'FamilyHistoryHypertension',
#        'FamilyHistoryDiabetes', 'PreviousAcuteKidneyInjury',
#        'UrinaryTractInfections', 'SystolicBP', 'DiastolicBP',
#        'FastingBloodSugar', 'HbA1c', 'SerumCreatinine', 'BUNLevels', 'GFR',
#        'ProteinInUrine', 'ACR', 'SerumElectrolytesSodium',
#        'SerumElectrolytesPotassium', 'SerumElectrolytesCalcium',
#        'SerumElectrolytesPhosphorus', 'HemoglobinLevels', 'CholesterolTotal',
#        'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides',
#        'ACEInhibitors', 'Diuretics', 'NSAIDsUse', 'Statins',
#        'AntidiabeticMedications', 'Edema', 'FatigueLevels', 'NauseaVomiting',
#        'MuscleCramps', 'Itching', 'QualityOfLifeScore', 'HeavyMetalsExposure',
# ...

# %%
average_bmi_by_gender = df.groupby('Gender')['BMI'].mean()
print(average_bmi_by_gender)
# Out:
# Gender
# 0    27.795734
# 1    27.454843
# Name: BMI, dtype: float64

# %% [markdown]
# #### Question 2: How does the distribution of Systolic Blood Pressure vary across different age groups?

# %%
# Create age groups
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 20, 40, 60, 80, 100], labels=['0-20', '21-40', '41-60', '61-80', '81-100'])

# %%
# Box plot
sns.boxplot(x='AgeGroup', y='SystolicBP', data=df)
plt.xlabel('Age Group')
plt.ylabel('Systolic Blood Pressure')
plt.title('Distribution of Systolic Blood Pressure across Age Groups')
plt.show()

# %% [markdown]
# #### Question 3: What is the correlation between Fasting Blood Sugar and HbA1c levels?
# We will compute the correlation between these two columns and visualize it using a scatter plot.

# %%
# Calculate correlation
correlation = df['FastingBloodSugar'].corr(df['HbA1c'])
print(f'Correlation between Fasting Blood Sugar and HbA1c: {correlation}')
# Out:
# Correlation between Fasting Blood Sugar and HbA1c: 0.045503408269487594

# %%
# Scatter plot
plt.scatter(df['FastingBloodSugar'], df['HbA1c'], color='green')
plt.xlabel('Fasting Blood Sugar')
plt.ylabel('HbA1c')
plt.title('Fasting Blood Sugar vs HbA1c')
plt.show()

# %% [markdown]
# #### Question 4: How does the average Physical Activity level vary across different Socioeconomic Status categories?
# We will group the dataset by Socioeconomic Status and compute the mean Physical Activity level for each group.

# %%
# Group by Socioeconomic Status and calculate mean Physical Activity
average_physical_activity_by_socioeconomic_status = df.groupby('SocioeconomicStatus')['PhysicalActivity'].mean()
print(average_physical_activity_by_socioeconomic_status)
# Out:
# SocioeconomicStatus
# 0    4.965360
# 1    5.118597
# 2    4.958853
# Name: PhysicalActivity, dtype: float64

# %% [markdown]
# #### Question 5: What is the distribution of diagnoses in the dataset?
# We will create a bar plot to visualize the distribution of different diagnoses.

# %%
# Count plot
sns.countplot(x='Diagnosis', data=df)
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.title('Distribution of Diagnoses')
plt.show()

# %% [markdown]
# #### Question: What is the relationship between Alcohol Consumption and Sleep Quality?
# We will visualize this relationship using a scatter plot and compute the correlation.

# %%
# Calculate correlation
correlation_alcohol_sleep = df['AlcoholConsumption'].corr(df['SleepQuality'])
print(f'Correlation between Alcohol Consumption and Sleep Quality: {correlation_alcohol_sleep}')
# Out:
# Correlation between Alcohol Consumption and Sleep Quality: 0.025684297723232826

# %%
# Scatter plot
plt.scatter(df['AlcoholConsumption'], df['SleepQuality'], color = 'purple')
plt.xlabel('Alcohol Consumption')
plt.ylabel('Sleep Quality')
plt.title('Alcohol Consumption vs Sleep Quality')
plt.show()

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
# import jovian

# %%
# jovian.commit()

# %% [markdown]
# ## Inferences and Conclusion
#
# ### Summary of Inferences and Conclusions
#
# Through the detailed analysis and visualizations of the dataset, we have drawn several inferences and conclusions. Here is a summary of our findings:
#
# 1. **Average BMI by Gender**:
#    - The average BMI for each gender was computed, showing how body mass index varies between males and females. This provides insights into potential gender-related differences in body composition.
#
# 2. **Distribution of Systolic Blood Pressure across Age Groups**:
#    - By creating age groups and plotting the distribution of Systolic Blood Pressure, we observed how blood pressure varies with age. This can help identify age groups at higher risk of hypertension.
#
# 3. **Correlation between Fasting Blood Sugar and HbA1c Levels**:
#    - A strong positive correlation was found between Fasting Blood Sugar and HbA1c levels, indicating that higher blood sugar levels are associated with higher HbA1c levels. This is consistent with the medical understanding that both metrics are indicators of blood sugar control.
#
# 4. **Average Physical Activity by Socioeconomic Status**:
#    - The analysis showed variations in physical activity levels across different socioeconomic statuses. This highlights how socioeconomic factors may influence lifestyle choices related to physical activity.
#
# 5. **Distribution of Diagnoses**:
#    - The distribution of various diagnoses was visualized, providing an overview of the most common health conditions in the dataset. This helps in understanding the prevalence of different health issues.
#
# 6. **Relationship between Alcohol Consumption and Sleep Quality**:
#    - A scatter plot and correlation analysis revealed the relationship between alcohol consumption and sleep quality. This can inform further investigation into how lifestyle choices impact sleep.
#
# 7. **Prevalence of Smoking across Education Levels**:
#    - The prevalence of smoking was analyzed across different education levels, showing how education might influence smoking habits. This can guide public health interventions targeting smoking cessation.
#
# 8. **Distribution of Physical Activity across Age Groups**:
#    - The distribution of physical activity levels was examined across different age groups, providing insights into how physical activity varies with age and identifying age groups that may need more encouragement to stay active.
#
# 9. **Diet Quality by Socioeconomic Status and Ethnicity**:
#    - The analysis showed how diet quality varies across different socioeconomic statuses and ethnicities, highlighting potential disparities in diet and nutrition that could be addressed through targeted interventions.
#
# 10. **Serum Creatinine Levels and Family History of Diabetes**:
#     - The average Serum Creatinine levels were compared for patients with and without a family history of diabetes, providing insights into how genetics might influence kidney function markers.
#
# 11. **Risk Factor Score**:
#     - A new composite score was created based on BMI, Smoking, Alcohol Consumption, and Physical Activity to quantify overall health risk. This score can be used to identify high-risk individuals for targeted health interventions.
#
# 12. **Pivot Table for HbA1c Levels**:
#     - A pivot table summarized the average HbA1c levels by gender and ethnicity, providing a detailed view of how blood sugar control varies across these demographics.
#
# ### Conclusions
#
# 1. **Gender and Health Metrics**:
#    - Significant differences exist in health metrics such as BMI between genders, which may require gender-specific health strategies.
#
# 2. **Age and Health Risks**:
#    - Blood pressure and physical activity levels show clear trends across different age groups, indicating the need for age-specific health monitoring and interventions.
#
# 3. **Socioeconomic and Educational Influences**:
#    - Socioeconomic status and education level significantly influence health behaviors such as physical activity, diet, and smoking, underscoring the importance of addressing social determinants of health.
#
# 4. **Genetic and Lifestyle Factors**:
#    - Both genetic factors (e.g., family history of diabetes) and lifestyle choices (e.g., alcohol consumption, smoking) play crucial roles in determining health outcomes, suggesting a need for personalized and comprehensive health management approaches.
#
# 5. **Disparities in Health Outcomes**:
#    - Disparities in health outcomes across different ethnic and socioeconomic groups highlight the need for equitable healthcare access and tailored health promotion programs.
#
# By systematically answering these questions and using various data analysis techniques, we have gained a deeper understanding of the factors influencing health in this dataset. These insights can inform public health strategies, medical research, and individual health management plans.

# %%
# import jovian

# %%
# jovian.commit()

# %% [markdown]
# ## References and Future Work
#
# **TODO** - Write some explanation here: ideas for future projects using this dataset, and links to resources you found useful.

# %% [markdown]
# > Submission Instructions (delete this cell)
# >
# > - Upload your notebook to your Jovian.ml profile using `jovian.commit`.
# > - **Make a submission here**: https://jovian.ml/learn/data-analysis-with-python-zero-to-pandas/assignment/course-project
# > - Share your work on the forum: https://jovian.ml/forum/t/course-project-on-exploratory-data-analysis-discuss-and-share-your-work/11684
# > - Share your work on social media (Twitter, LinkedIn, Telegram etc.) and tag [@JovianML](https://twitter.com/jovianml)
# >
# > (Optional) Write a blog post
# >
# > - A blog post is a great way to present and showcase your work.
# > - Sign up on [Medium.com](https://medium.com) to write a blog post for your project.
# > - Copy over the explanations from your Jupyter notebook into your blog post, and [embed code cells & outputs](https://medium.com/jovianml/share-and-embed-jupyter-notebooks-online-with-jovian-ml-df709a03064e)
# > - Check out the Jovian.ml Medium publication for inspiration: https://medium.com/jovianml

# %%
# import jovian

# %%
jovian.commit(filename=filename)
# Out:
# [jovian] Updating notebook "uzairhussain193/zerotopandas-course-project" on https://jovian.com/
# [jovian] Committed successfully! https://jovian.com/uzairhussain193/zerotopandas-course-project
# 'https://jovian.com/uzairhussain193/zerotopandas-course-project'
